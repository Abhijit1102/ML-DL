# %% [markdown]
# ## Backpropogation
# epochs=5
# - fror i in range(epochs):
#   - select 1 rows (randim)
#   - predict(using forward propogation)
#   - cal loss fuction
#   - update weiegt and bias using GD
#        - Wn = Wo -ndl/dw
#
# - loss functiuon is a function of all the trainable parameter.
#
# "https://developers-dot-devsite-v2-prod.appspot.com/machine-learning/crash-course/backprop-scroll"

# %% [markdown]
# ## Gradient Desent
# - There are three variant of gradient decent, which differ in how much data we use to compute the gradient of object function. Depending on the amount of data, we make a trade-off between the acurracy of parameter update and time it takes to perform an update.
#   - Batch GD(valina GD):
#               Entire dataset -> predict y_hat for entire data -> cal loss & update weights & Bais for no of epoaches.
#
#   - Stochastics GD :
#                 Suffle the entire data -> in the loop sufle randomly select a row cal y_hat -> cal weights and bias -> come outside the loop -> calculate average  loss then update wieghts and bias.
#
#   - Mini Batch GD:
#              make batches -> In every epoch updates -> in each batches -> predict -> cal culate loss function -> updates weights and bias
#
#              - in terms of  convergence: SGD> M-BGD > Batch GD in terms of speed viz.

# %% [markdown]
# ### Batch vs Stochastic GD

# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df = df[['Age','EstimatedSalary','Purchased']]

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=500,batch_size=1,validation_split=0.2) # Batch size=1 then stochastic
#print(time.time() - start)
# Out:
# Epoch 1/500
# 320/320 [==============================] - 2s 4ms/step - loss: 0.6090 - accuracy: 0.7750 - val_loss: 0.5713 - val_accuracy: 0.7375
# Epoch 2/500
# 320/320 [==============================] - 1s 3ms/step - loss: 0.4440 - accuracy: 0.8188 - val_loss: 0.5252 - val_accuracy: 0.7125
# Epoch 3/500
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3457 - accuracy: 0.8344 - val_loss: 0.4145 - val_accuracy: 0.7750
# Epoch 4/500
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3074 - accuracy: 0.8562 - val_loss: 0.3450 - val_accuracy: 0.8250
# Epoch 5/500
# 320/320 [==============================] - 1s 3ms/step - loss: 0.2961 - accuracy: 0.8625 - val_loss: 0.3119 - val_accuracy: 0.8750
# Epoch 6/500
# 320/320 [==============================] - 1s 3ms/step - loss: 0.2899 - accuracy: 0.8687 - val_loss: 0.2878 - val_accuracy: 0.8875
# Epoch 7/500
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=250,validation_split=0.2) #Batch gradient decent
print(time.time() - start)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 274ms/step - loss: 0.6424 - accuracy: 0.6969 - val_loss: 0.7238 - val_accuracy: 0.3625
# Epoch 2/10
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6303 - accuracy: 0.7125 - val_loss: 0.7223 - val_accuracy: 0.3625
# Epoch 3/10
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6225 - accuracy: 0.7125 - val_loss: 0.7215 - val_accuracy: 0.3625
# Epoch 4/10
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6161 - accuracy: 0.7125 - val_loss: 0.7195 - val_accuracy: 0.3625
# Epoch 5/10
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6105 - accuracy: 0.7125 - val_loss: 0.7191 - val_accuracy: 0.3625
# Epoch 6/10
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6052 - accuracy: 0.7125 - val_loss: 0.7193 - val_accuracy: 0.3625
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
