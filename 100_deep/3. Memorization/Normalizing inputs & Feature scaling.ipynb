# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df = df.iloc[:,2:]
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
import seaborn as sns
sns.scatterplot(x=df.iloc[:,0],y=df.iloc[:,1])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='EstimatedSalary'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

model = Sequential()

model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 38ms/step - loss: 170.3911 - accuracy: 0.4969 - val_loss: 166.7647 - val_accuracy: 0.6000
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 107.3813 - accuracy: 0.5406 - val_loss: 183.1782 - val_accuracy: 0.6000
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 62.8629 - accuracy: 0.5219 - val_loss: 29.3500 - val_accuracy: 0.4000
# Epoch 4/100
# 10/10 [==============================] - 0s 11ms/step - loss: 30.6199 - accuracy: 0.4812 - val_loss: 15.1297 - val_accuracy: 0.6000
# Epoch 5/100
# 10/10 [==============================] - 0s 11ms/step - loss: 27.1423 - accuracy: 0.5281 - val_loss: 22.3891 - val_accuracy: 0.4000
# Epoch 6/100
# 10/10 [==============================] - 0s 11ms/step - loss: 20.1818 - accuracy: 0.5594 - val_loss: 21.2143 - val_accuracy: 0.4000
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# ### Advatages of Normalized data
# - Unormalized data is uneven about all axis
# - But Normalized data is symmetrical and not oscilate more on apply gradient descent and it will converge fastly to solution comparatively.

# %% [markdown]
# ## Applying scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train_scaled,y_train,validation_data=(X_test_scaled,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 41ms/step - loss: 0.6897 - accuracy: 0.4875 - val_loss: 0.6478 - val_accuracy: 0.8875
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6307 - accuracy: 0.8687 - val_loss: 0.5902 - val_accuracy: 0.8625
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5809 - accuracy: 0.8719 - val_loss: 0.5409 - val_accuracy: 0.8125
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5376 - accuracy: 0.8562 - val_loss: 0.5000 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5000 - accuracy: 0.8594 - val_loss: 0.4653 - val_accuracy: 0.8125
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4679 - accuracy: 0.8656 - val_loss: 0.4347 - val_accuracy: 0.8375
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])
